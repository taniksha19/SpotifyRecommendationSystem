# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.ticker as plticker
from matplotlib import pyplot as plt
# %matplotlib inline

sns.set(context='notebook', style='darkgrid', palette='deep', font='sans-serif', font_scale=1, color_codes=False, rc=None)

# %%
df=pd.read_csv("final.csv")
df.head()
# Out:
#    Unnamed: 0                             name           endTime  \
# 0           0                YEAH RIGHT___Joji  2022-01-10 13:08
# 1           1     Need You Tonight___JP Cooper  2022-02-21 14:55
# 2           2         Arcade___Duncan Laurence  2022-02-21 18:25
# 3           3  SLOW DANCING IN THE DARK___Joji  2022-02-24 08:45
# 4           4  SLOW DANCING IN THE DARK___Joji  2022-02-24 08:47
#
#         artistName                 trackName  msPlayed             datetime  \
# 0             Joji                YEAH RIGHT     15146  2022-01-10 13:08:00
# 1        JP Cooper          Need You Tonight    134342  2022-02-21 14:55:00
# 2  Duncan Laurence                    Arcade     78732  2022-02-21 18:25:00
# 3             Joji  SLOW DANCING IN THE DARK     75541  2022-02-24 08:45:00
# 4             Joji  SLOW DANCING IN THE DARK    133522  2022-02-24 08:47:00
#
#    danceability  energy  key  ...    tempo            type  \
# 0         0.672   0.588    1  ...  169.033  audio_features
# 1         0.521   0.682    2  ...  143.834  audio_features
# 2         0.450   0.329    9  ...   71.884  audio_features
# 3         0.515   0.479    3  ...   88.964  audio_features
# 4         0.515   0.479    3  ...   88.964  audio_features
#
#                        id                                   uri  \
# 0  1VGzxJnVQND7Cg5H5wGj14  spotify:track:1VGzxJnVQND7Cg5H5wGj14
# 1  4HLuopIC1sQIgTAcDwkkqR  spotify:track:4HLuopIC1sQIgTAcDwkkqR
# 2  1Xi84slp6FryDSCbzq4UCD  spotify:track:1Xi84slp6FryDSCbzq4UCD
# 3  0rKtyWc8bvkriBthvHKY8d  spotify:track:0rKtyWc8bvkriBthvHKY8d
# 4  0rKtyWc8bvkriBthvHKY8d  spotify:track:0rKtyWc8bvkriBthvHKY8d
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1VGzxJnVQND7...
# 1  https://api.spotify.com/v1/tracks/4HLuopIC1sQI...
# 2  https://api.spotify.com/v1/tracks/1Xi84slp6Fry...
# 3  https://api.spotify.com/v1/tracks/0rKtyWc8bvkr...
# 4  https://api.spotify.com/v1/tracks/0rKtyWc8bvkr...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1VGz...       174358
# 1  https://api.spotify.com/v1/audio-analysis/4HLu...       198301
# 2  https://api.spotify.com/v1/audio-analysis/1Xi8...       183624
# 3  https://api.spotify.com/v1/audio-analysis/0rKt...       209274
# 4  https://api.spotify.com/v1/audio-analysis/0rKt...       209274
#
#    time_signature         albumName                 albumID
# 0               4         BALLADS 1  34GQP3dILpyCN018y2k61L
# 1               4  Need You Tonight  2vVY1FESWAdXJLyF7vd7w8
# 2               3            Arcade  7BISGeB7QwhqRIadxuLHfG
# 3               4         BALLADS 1  34GQP3dILpyCN018y2k61L
# 4               4         BALLADS 1  34GQP3dILpyCN018y2k61L
#
# [5 rows x 27 columns]

# %%
df.tail()
# Out:
#       Unnamed: 0                                               name  \
# 6423        6423                      Sure Thing - Sped Up___Miguel
# 6424        6424                                Players___Coi Leray
# 6425        6425                        I Like Him___Princess Nokia
# 6426        6426  SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis an...
# 6427        6427                             Afterglow___Ed Sheeran
#
#                endTime      artistName  \
# 6423  2023-02-22 19:24          Miguel
# 6424  2023-02-22 19:26       Coi Leray
# 6425  2023-02-22 19:30  Princess Nokia
# 6426  2023-02-22 19:30         Amaarae
# 6427  2023-02-23 14:32      Ed Sheeran
#
#                                               trackName  msPlayed  \
# 6423                               Sure Thing - Sped Up    149860
# 6424                                            Players    139450
# 6425                                         I Like Him    132333
# 6426  SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis an...    204718
# 6427                                          Afterglow    176998
#
#                  datetime  danceability  energy  key  ...    tempo  \
# 6423  2023-02-22 19:24:00         0.753   0.458    4  ...  105.057
# 6424  2023-02-22 19:26:00         0.954   0.516    6  ...  105.001
# 6425  2023-02-22 19:30:00         0.893   0.579    9  ...  133.018
# 6426  2023-02-22 19:30:00         0.870   0.523    1  ...  110.020
# 6427  2023-02-23 14:32:00         0.641   0.324   11  ...  110.184
#
#                 type                      id  \
# 6423  audio_features  559SdaPI7mqy9IQiscuaMj
# 6424  audio_features  6UN73IYd0hZxLi8wFPMQij
# 6425  audio_features  68UU9oaQtMDnh6PRlW842H
# 6426  audio_features  09gysnJpfQ3ublBmJDfcEC
# 6427  audio_features  0E4Y1XIbs8GrAT1YqVy6dq
#
#                                        uri  \
# 6423  spotify:track:559SdaPI7mqy9IQiscuaMj
# 6424  spotify:track:6UN73IYd0hZxLi8wFPMQij
# 6425  spotify:track:68UU9oaQtMDnh6PRlW842H
# 6426  spotify:track:09gysnJpfQ3ublBmJDfcEC
# 6427  spotify:track:0E4Y1XIbs8GrAT1YqVy6dq
#
#                                              track_href  \
# 6423  https://api.spotify.com/v1/tracks/559SdaPI7mqy...
# 6424  https://api.spotify.com/v1/tracks/6UN73IYd0hZx...
# 6425  https://api.spotify.com/v1/tracks/68UU9oaQtMDn...
# 6426  https://api.spotify.com/v1/tracks/09gysnJpfQ3u...
# 6427  https://api.spotify.com/v1/tracks/0E4Y1XIbs8Gr...
#
#                                            analysis_url  duration_ms  \
# 6423  https://api.spotify.com/v1/audio-analysis/559S...       150054
# 6424  https://api.spotify.com/v1/audio-analysis/6UN7...       139560
# 6425  https://api.spotify.com/v1/audio-analysis/68UU...       132453
# 6426  https://api.spotify.com/v1/audio-analysis/09gy...       204764
# 6427  https://api.spotify.com/v1/audio-analysis/0E4Y...       185487
#
#       time_signature                                          albumName  \
# 6423               4                               Sure Thing (Sped Up)
# 6424               4                                            Players
# 6425               4                                   Everything Sucks
# 6426               4  SAD GIRLZ LUV MONEY Remix (feat. Kali Uchis an...
# 6427               4                                          Afterglow
#
#                      albumID
# 6423  0IrjdFRneYtHj0CwmAphDT
# 6424  4cAAsw7mPkGt15GXQzWlrM
# 6425  6JP1xbkFnacGAvrIWW5pzF
# 6426  4q4rHdKxyCzxuQrPcdjPyC
# 6427  5bb2Sf8jps2DTyI2urMThV
#
# [5 rows x 27 columns]

# %%
df.shape
# Out:
# (6428, 27)

# %%
# What song(s) are the most listened to of all time?
song_count  = df['trackName'].value_counts()
song_count = song_count[:10,]
plt.figure(figsize=(15,5))
chart = sns.barplot(song_count.index, song_count.values, alpha=0.8)
plt.title('Top 10 Songs All Time')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Song', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(song_count.index, rotation=30)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'name', 'endTime', 'artistName', 'trackName', 'msPlayed',
#        'datetime', 'danceability', 'energy', 'key', 'loudness', 'mode',
#        'speechiness', 'acousticness', 'instrumentalness', 'liveness',
#        'valence', 'tempo', 'type', 'id', 'uri', 'track_href', 'analysis_url',
#        'duration_ms', 'time_signature', 'albumName', 'albumID'],
#       dtype='object')

# %%
# Checking if these two columns are the same
df[['msPlayed', 'duration_ms']]
# Out:
#       msPlayed  duration_ms
# 0        15146       174358
# 1       134342       198301
# 2        78732       183624
# 3        75541       209274
# 4       133522       209274
# ...        ...          ...
# 6423    149860       150054
# 6424    139450       139560
# 6425    132333       132453
# 6426    204718       204764
# 6427    176998       185487
#
# [6428 rows x 2 columns]

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# name                0
# endTime             0
# artistName          0
# trackName           0
# msPlayed            0
# datetime            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# albumName           1
# albumID             1
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0          0
# name                0
# endTime             0
# artistName          0
# trackName           0
# msPlayed            0
# datetime            0
# danceability        0
# energy              0
# key                 0
# loudness            0
# mode                0
# speechiness         0
# acousticness        0
# instrumentalness    0
# liveness            0
# valence             0
# tempo               0
# type                0
# id                  0
# uri                 0
# track_href          0
# analysis_url        0
# duration_ms         0
# time_signature      0
# albumName           0
# albumID             0
# dtype: int64

# %%
# Converting time columns to dt format
df['endTime'] = pd.to_datetime(df['endTime'])
df['datetime'] = pd.to_datetime(df['datetime'])

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, name, endTime, artistName, trackName, msPlayed, datetime, danceability, energy, key, loudness, mode, speechiness, acousticness, instrumentalness, liveness, valence, tempo, type, id, uri, track_href, analysis_url, duration_ms, time_signature, albumName, albumID]
# Index: []
#
# [0 rows x 27 columns]

# %%
# Create new columns with song name & artist
df['name'] = df['name'].str.replace('___',' by ')

# %%
# Create new column with minutes listened to
df['minutesPlayed'] = df['msPlayed'] / 60000

# %%
# Create new column with total length of song in minutes
df['totalMinutes'] = df['duration_ms'] / 60000

# %%
# Create column with only day, time, hour, year
df['date'] = [d.date() for d in df['endTime']]
df['time'] = [d.time() for d in df['endTime']]
df['day'] = df['endTime'].dt.day
df['hour'] = df['endTime'].dt.hour
df['month'] = df['endTime'].dt.month_name()
df['year'] = df['endTime'].dt.year
df['dayName'] = df['endTime'].dt.day_name()

# %%
# Saving a copy of this dataframe for later
xy = df.copy()

# %%
xy.head()
# Out:
#    Unnamed: 0                              name             endTime  \
# 0           0                YEAH RIGHT by Joji 2022-01-10 13:08:00
# 1           1     Need You Tonight by JP Cooper 2022-02-21 14:55:00
# 2           2         Arcade by Duncan Laurence 2022-02-21 18:25:00
# 3           3  SLOW DANCING IN THE DARK by Joji 2022-02-24 08:45:00
# 4           4  SLOW DANCING IN THE DARK by Joji 2022-02-24 08:47:00
#
#         artistName                 trackName  msPlayed            datetime  \
# 0             Joji                YEAH RIGHT     15146 2022-01-10 13:08:00
# 1        JP Cooper          Need You Tonight    134342 2022-02-21 14:55:00
# 2  Duncan Laurence                    Arcade     78732 2022-02-21 18:25:00
# 3             Joji  SLOW DANCING IN THE DARK     75541 2022-02-24 08:45:00
# 4             Joji  SLOW DANCING IN THE DARK    133522 2022-02-24 08:47:00
#
#    danceability  energy  key  ...                 albumID  minutesPlayed  \
# 0         0.672   0.588    1  ...  34GQP3dILpyCN018y2k61L       0.252433
# 1         0.521   0.682    2  ...  2vVY1FESWAdXJLyF7vd7w8       2.239033
# 2         0.450   0.329    9  ...  7BISGeB7QwhqRIadxuLHfG       1.312200
# 3         0.515   0.479    3  ...  34GQP3dILpyCN018y2k61L       1.259017
# 4         0.515   0.479    3  ...  34GQP3dILpyCN018y2k61L       2.225367
#
#    totalMinutes        date      time  day  hour     month  year   dayName
# 0      2.905967  2022-01-10  13:08:00   10    13   January  2022    Monday
# 1      3.305017  2022-02-21  14:55:00   21    14  February  2022    Monday
# 2      3.060400  2022-02-21  18:25:00   21    18  February  2022    Monday
# 3      3.487900  2022-02-24  08:45:00   24     8  February  2022  Thursday
# 4      3.487900  2022-02-24  08:47:00   24     8  February  2022  Thursday
#
# [5 rows x 36 columns]

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    Unnamed: 0                              name             endTime  \
# 0           0                YEAH RIGHT by Joji 2022-01-10 13:08:00
# 1           1     Need You Tonight by JP Cooper 2022-02-21 14:55:00
# 2           2         Arcade by Duncan Laurence 2022-02-21 18:25:00
# 3           3  SLOW DANCING IN THE DARK by Joji 2022-02-24 08:45:00
# 4           4  SLOW DANCING IN THE DARK by Joji 2022-02-24 08:47:00
#
#         artistName                 trackName  msPlayed            datetime  \
# 0             Joji                YEAH RIGHT     15146 2022-01-10 13:08:00
# 1        JP Cooper          Need You Tonight    134342 2022-02-21 14:55:00
# 2  Duncan Laurence                    Arcade     78732 2022-02-21 18:25:00
# 3             Joji  SLOW DANCING IN THE DARK     75541 2022-02-24 08:45:00
# 4             Joji  SLOW DANCING IN THE DARK    133522 2022-02-24 08:47:00
#
#    danceability  energy  key  ...                 albumID  minutesPlayed  \
# 0         0.672   0.588    1  ...  34GQP3dILpyCN018y2k61L       0.252433
# 1         0.521   0.682    2  ...  2vVY1FESWAdXJLyF7vd7w8       2.239033
# 2         0.450   0.329    9  ...  7BISGeB7QwhqRIadxuLHfG       1.312200
# 3         0.515   0.479    3  ...  34GQP3dILpyCN018y2k61L       1.259017
# 4         0.515   0.479    3  ...  34GQP3dILpyCN018y2k61L       2.225367
#
#    totalMinutes        date      time  day  hour     month  year   dayName
# 0      2.905967  2022-01-10  13:08:00   10    13   January  2022    Monday
# 1      3.305017  2022-02-21  14:55:00   21    14  February  2022    Monday
# 2      3.060400  2022-02-21  18:25:00   21    18  February  2022    Monday
# 3      3.487900  2022-02-24  08:45:00   24     8  February  2022  Thursday
# 4      3.487900  2022-02-24  08:47:00   24     8  February  2022  Thursday
#
# [5 rows x 36 columns]

# %%
df.shape
# Out:
# (6427, 36)

# %%
# What song(s) are the most listened to of all time?
song_count  = df['name'].value_counts()
song_count = song_count[:10,]
plt.figure(figsize=(15,5))
chart = sns.barplot(song_count.index, song_count.values, alpha=0.8)
plt.title('Top 10 Songs All Time')
plt.ylabel('Number of Occurrences', fontsize=12)
plt.xlabel('Song', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(song_count.index, rotation=30)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# What arttists are the most listened to of all time?
song_count = df['artistName'].value_counts()
song_count = song_count[:10]
plt.figure(figsize=(15,5))
chart = sns.barplot(song_count.index, song_count.values, alpha=0.8)
plt.title('Top 10 Artists All Time')
plt.ylabel('Number of Songs Listened To', fontsize=12)
plt.xlabel('Artist', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(song_count.index, rotation=30)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Look at most popular artists by amount of time spent listening to their songs
amount_of_time = df.groupby(by='artistName')['minutesPlayed'].sum().sort_values(ascending=False)[:15]

amount_of_time
# Out:
# artistName
# Taylor Swift      460.925933
# Harry Styles      327.163733
# Anuv Jain         274.516133
# One Direction     267.379750
# Prateek Kuhad     239.039767
# The Weeknd        238.494383
# Billie Eilish     216.273350
# SZA               196.407650
# Ariana Grande     168.460933
# Selena Gomez      159.678133
# Joji              155.160117
# Olivia Rodrigo    147.634283
# Conan Gray        147.408300
# Justin Bieber     131.666800
# Doja Cat          123.340167
# Name: minutesPlayed, dtype: float64

# %%
# What artists have the most time listened to?
b = df.groupby('artistName')['minutesPlayed'].sum().sort_values(ascending=False)[:10].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(b['artistName'], b['minutesPlayed'], alpha=0.8)
plt.title('Artists with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Artist', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(b['artistName'], rotation=30)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# What songs have the most minutes spent listening to?
c = df.groupby('name')['minutesPlayed'].sum().sort_values(ascending=False)[:10].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(c['name'], c['minutesPlayed'], alpha=0.8)
plt.title('Songs with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Song', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(c['name'], rotation=90)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# How has the amount of music listened to per day changed over time?
d = df.groupby('date')['minutesPlayed'].sum().reset_index()
chart = sns.relplot(x='date', y='minutesPlayed', kind="line", data=d).set(title='Timeline of Minutes Played')
chart.fig.autofmt_xdate()
chart.fig.set_figwidth(8.27)
chart.fig.set_figheight(5.7)
chart.set(xlabel='Date', ylabel='Minutes Played')

# %%
# Which day of the week has the most minutes listened to?
e = df.groupby('dayName')['minutesPlayed'].sum().sort_values(ascending=False)[:10].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(e['dayName'], e['minutesPlayed'], alpha=0.8)
plt.title('Days with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Day', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(e['dayName'], rotation=90)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
#Which month of the year has the most minutes of music listened to?
e = df.groupby('month')['minutesPlayed'].sum().sort_values(ascending=False)[:5].reset_index()
plt.figure(figsize=(15,5))
chart = sns.barplot(e['month'], e['minutesPlayed'], alpha=0.8)
plt.title('Months with Most Time Listened in Minutes')
plt.ylabel('Minutes', fontsize=12)
plt.xlabel('Month', fontsize=12)
xticks=chart.xaxis.get_major_ticks()
chart.set_xticklabels(e['month'], rotation=90)

plt.show()
# Out:
# C:\Users\HP\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Creating new dateframe to analyze only audio features. 
df = df[['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo','endTime', 'day', 'hour', 'month', 'year', 'dayName']]
af = ['danceability', 'energy', 'key', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']
df.head()
# Out:
#    danceability  energy  key  loudness  speechiness  acousticness  \
# 0         0.672   0.588    1    -9.573       0.1330         0.619
# 1         0.521   0.682    2    -2.707       0.0487         0.439
# 2         0.450   0.329    9   -12.603       0.0441         0.818
# 3         0.515   0.479    3    -7.458       0.0261         0.544
# 4         0.515   0.479    3    -7.458       0.0261         0.544
#
#    instrumentalness  liveness  valence    tempo             endTime  day  \
# 0           0.24100    0.0992    0.204  169.033 2022-01-10 13:08:00   10
# 1           0.00000    0.1490    0.287  143.834 2022-02-21 14:55:00   21
# 2           0.00109    0.1350    0.266   71.884 2022-02-21 18:25:00   21
# 3           0.00598    0.1910    0.284   88.964 2022-02-24 08:45:00   24
# 4           0.00598    0.1910    0.284   88.964 2022-02-24 08:47:00   24
#
#    hour     month  year   dayName
# 0    13   January  2022    Monday
# 1    14  February  2022    Monday
# 2    18  February  2022    Monday
# 3     8  February  2022  Thursday
# 4     8  February  2022  Thursday

# %%
# Understanding how song features relate
corr = df.corr()
plt.figure(figsize=(12,8))
sns.heatmap(corr, annot=True).set(title='Coorelations Between Song Features')
# Out:
# [Text(0.5, 1.0, 'Coorelations Between Song Features')]

# %%
# What is the average value for each audio feature?
for feature in af:
    sns.boxplot(showfliers = False, x=df[feature])
    plt.show()

# %%
# What is the variance of each feature per day?(Hidden output)
for feature in af:
    ax = sns.boxplot(x="dayName", y=feature, data=df, showfliers = False)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
    plt.title(feature.title() + ' Variance per Day')
    plt.show()

# %%
# What is the variance of each feature per month? (Hidden output)
for feature in af:
    ax = sns.boxplot(x="month", y=feature, data=df, showfliers = False)
    ax.set_xticklabels(ax.get_xticklabels(),rotation=30)
    plt.title(feature.title() + ' Variance per Month')
    plt.show()

# %%
# What is the variance of each feature per year? (Hidden output)
for feature in af:
    ax = sns.boxplot(x="year", y=feature, data=df, showfliers = False)
    plt.title(feature.title() + ' in 2020 vs. 2021')
    plt.show()

# %% [markdown]
# # Top 100

# %%
# Creating a new dataframe with audio features of top 100 songs
song_count = xy['name'].value_counts()[:100]
xy = xy.loc[xy['name'].isin(song_count.index)].drop_duplicates(subset=['name'])
xy.head()
# Out:
#     Unnamed: 0                                   name             endTime  \
# 3            3       SLOW DANCING IN THE DARK by Joji 2022-02-24 08:45:00
# 8            8  Get You The Moon (feat. Snøw) by Kina 2022-02-24 08:57:00
# 11          11           Coffee Breath by Sofia Mills 2022-02-24 09:08:00
# 16          16                     July by Noah Cyrus 2022-02-24 09:20:00
# 18          18    Let Me Down Slowly by Alec Benjamin 2022-02-24 09:26:00
#
#        artistName                      trackName  msPlayed  \
# 3            Joji       SLOW DANCING IN THE DARK     75541
# 8            Kina  Get You The Moon (feat. Snøw)    178842
# 11    Sofia Mills                  Coffee Breath    163694
# 16     Noah Cyrus                           July    156077
# 18  Alec Benjamin             Let Me Down Slowly    169322
#
#               datetime  danceability  energy  key  ...  \
# 3  2022-02-24 08:45:00         0.515   0.479    3  ...
# 8  2022-02-24 08:57:00         0.498   0.235    1  ...
# 11 2022-02-24 09:08:00         0.866   0.211   11  ...
# 16 2022-02-24 09:20:00         0.708   0.186    9  ...
# 18 2022-02-24 09:26:00         0.652   0.557    1  ...
#
#                    albumID  minutesPlayed  totalMinutes        date      time  \
# 3   34GQP3dILpyCN018y2k61L       1.259017      3.487900  2022-02-24  08:45:00
# 8   5LZSpPoBVBsh6kRSEKfPQ8       2.980700      2.984667  2022-02-24  08:57:00
# 11  6PLQWrmCo4IDIbfaIP2hAE       2.728233      2.731700  2022-02-24  09:08:00
# 16  5Gn3fFzlWL89j0hGumtXb5       2.601283      2.601767  2022-02-24  09:20:00
# 18  6jKZplJpy21R5lHaYHHjmZ       2.822033      2.822567  2022-02-24  09:26:00
#
#     day  hour     month  year   dayName
# 3    24     8  February  2022  Thursday
# 8    24     8  February  2022  Thursday
# 11   24     9  February  2022  Thursday
# 16   24     9  February  2022  Thursday
# 18   24     9  February  2022  Thursday
#
# [5 rows x 36 columns]

# %%
# What is the average value for each audio feature? (Hidden output)
for feature in af:
    sns.boxplot(showfliers = False, x=xy[feature])
    plt.show()

# %% [markdown]
# # Checking the happiness/valence of tracks in the top 100

# %%
less_count, more_count, middle_count = 0, 0, 0
for num in xy['valence']:
    if num >= 0 and num <0.5: 
        less_count += 1
    elif num >=0.5 and num < 0.6:
        middle_count += 1
    else: 
        more_count += 1

print("Songs with Valence < 0.5: ", less_count) 
print("Songs with Valence > 0.6: ", more_count)
print("Songs with Valence between 0.5 and 0.6: ", middle_count)
# Out:
# Songs with Valence < 0.5:  70
# Songs with Valence > 0.6:  16
# Songs with Valence between 0.5 and 0.6:  14
